# %% [markdown]
# # Data Cleaning

# %%
# Imports
import numpy as np, pandas as pd

# %%
# Read in data set: CCES 2010-14 panel
df_cces = pd.read_stata('../Data/CCES/CCES_Panel_Full3waves_VV_V4_LRS.dta')

# %%
# Have a brief look at the data set ==> Wide format
df_cces
# Out:
#        caseid    weight CC10_301_1 CC10_301_2 CC10_301_3 CC10_301_4  \
# 0     25233.0  0.538062        Yes        Yes        Yes        Yes
# 1     38716.0  3.470877        Yes         No        Yes        Yes
# 2      7796.0  0.602477         No        Yes        Yes        Yes
# 3     78113.0  0.264208        Yes        Yes        Yes        Yes
# 4     63800.0  0.196632        Yes        Yes        Yes         No
# ...       ...       ...        ...        ...        ...        ...
# 9495  57290.0  1.146715         No         No        Yes        Yes
# 9496  57315.0  1.171217         No         No         No        Yes
# 9497  57399.0  0.424949         No        Yes        Yes         No
# 9498  59331.0  0.505942         No        Yes         No        Yes
# 9499  66538.0  1.665605         No        Yes        Yes         No
#
#      CC10_301_5       CC10_301b CC10_301c               CC10_302  ...  \
# 0            No            Both     Print      Gotten much worse  ...
# 1            No             NaN      Both  Stayed about the same  ...
# 2            No            Both     Print           Gotten worse  ...
# 3            No            Both    Online          Gotten better  ...
# 4            No            Both      Both          Gotten better  ...
# ...         ...             ...       ...                    ...  ...
# 9495         No             NaN    Online          Gotten better  ...
# 9496         No             NaN       NaN  Stayed about the same  ...
# 9497         No            Both     Print          Gotten better  ...
# 9498         No  Local Newscast       NaN           Gotten worse  ...
# 9499         No  Local Newscast     Print  Stayed about the same  ...
#
#                     validated_reg_10 validated_reg_12 validated_reg_14  \
# 0                         Registered       Registered   No match found
# 1                         Registered       Registered       Registered
# 2                         Registered       Registered       Registered
# 3                         Registered       Registered       Registered
# 4                         Registered       Registered       Registered
# ...                              ...              ...              ...
# 9495                      Registered       Registered       Registered
# 9496                      Registered       Registered       Registered
# 9497  On multiple registration lists       Registered       Registered
# 9498                      Registered       Registered       Registered
# 9499                  No match found   No match found   No match found
#
#                     VV_general_10            VV_general_12  \
# 0     In person or unknown method                In person
# 1                      Mail voter               Mail voter
# 2                     Early voter              Early voter
# 3                  Absentee voter           Absentee voter
# 4                     Early voter                In person
# ...                           ...                      ...
# 9495          Confirmed Non-voter  Voted by unknown method
# 9496  In person or unknown method                In person
# 9497          Confirmed Non-voter                In person
# 9498  In person or unknown method                In person
# 9499                    Unmatched                Unmatched
#
#                 VV_general_14            VV_primary_10  \
# 0                   Unmatched         Voted in Primary
# 1                  Mail voter         Voted in Primary
# 2                 Early voter         Voted in Primary
# 3              Absentee voter         Voted in Primary
# 4                   In person  Did not vote in primary
# ...                       ...                      ...
# 9495  Voted by unknown method  Did not vote in primary
# 9496      Confirmed Non-voter  Did not vote in primary
# 9497      Confirmed Non-voter  Did not vote in primary
# 9498                In person         Voted in Primary
# 9499                Unmatched                Unmatched
#
#                 VV_primary_12            VV_primary_14      VV_pres_primary_12
# 0            Voted in Primary                Unmatched  No primary vote record
# 1            Voted in Primary         Voted in Primary  No primary vote record
# CC10_HouseVote_C
# CC10_HouseVote_C_post
# CC10_HouseVote_D
# CC10_HouseVote_D_post
# CC10_HouseVote_F
# CC10_HouseVote_F_post
# CC10_HouseVote_G
# CC10_HouseVote_G_post
# CC10_LegName
# CC10_LegName_post
# CC10_LowerChamberName
# CC10_LowerChamberName_post
# CC10_Ohousecan2party_post
# CC10_OtherGovCand2Gender
# CC10_OtherGovCand2Gender_post
# CC10_OtherGovCand2Name
# CC10_OtherGovCand2Name_post
# CC10_OtherGovCand2Party
# CC10_OtherGovCand2Party_post
# CC10_OtherGovCandGender
# CC10_OtherGovCandGender_post
# CC10_OtherGovCandName
# CC10_OtherGovCandName_post
# CC10_OtherGovCandParty
# CC10_OtherGovCandParty_post
# CC10_OtherHouseCand2Gender
# CC10_OtherHouseCand2Name
# CC10_OtherHouseCand2Name_post
# CC10_OtherHouseCandGender
# CC10_OtherHouseCandGender_post
# CC10_OtherHouseCandInc
# CC10_OtherHouseCandInc_post
# CC10_OtherHouseCandName
# CC10_OtherHouseCandName1
# CC10_OtherHouseCandName1_post
# CC10_OtherHouseCandName2
# CC10_OtherHouseCandName2_post
# CC10_OtherHouseCandName_08
# CC10_OtherHouseCandName_08_post
# CC10_OtherHouseCandName_post
# CC10_OtherHouseCandParty
# CC10_OtherHouseCandParty_post
# CC10_OtherSenCandGender
# CC10_OtherSenCandGender_post
# CC10_OtherSenCandInc
# CC10_OtherSenCandInc_post
# CC10_OtherSenCandName
# CC10_OtherSenCandName_post
# CC10_OtherSenCandParty
# CC10_OtherSenCandParty_post
# CC10_OtherSenCand_08
# CC10_OtherSenCand_08_post
# CC10_Otherhousecandidate2party
# CC10_Rsenatecandidategender_post
# CC10_SenCandDemGender_NY
# CC10_SenCandDemGender_NY_post
# CC10_SenCandDemInc_NY
# CC10_SenCandDemInc_NY_post
# CC10_SenCandDemName_NY
# CC10_SenCandDemName_NY_post
# CC10_SenCandGender_dem
# CC10_SenCandGender_post_dem
# CC10_SenCandGender_rep
# CC10_SenCandInc_dem
# CC10_SenCandInc_post_dem
# CC10_SenCandInc_post_rep
# CC10_SenCandInc_rep
# CC10_SenCandName_dem
# CC10_SenCandName_post_dem
# CC10_SenCandName_post_rep
# CC10_SenCandName_rep
# CC10_SenCandRepGender_NY
# CC10_SenCandRepGender_NY_post
# CC10_SenCandRepInc_NY
# CC10_SenCandRepInc_NY_post
# CC10_SenCandRepName_NY
# CC10_SenCandRepName_NY_post
# CC10_SenCand_Rep08
# CC10_SenCand_Rep08_post
# CC10_SenCandidate_Dem08
# CC10_SenCandidate_Dem08_post
# CC10_Senate1Vote_A
# CC10_Senate1Vote_A_post
# CC10_Senate1Vote_B
# CC10_Senate1Vote_B_post
# CC10_Senate1Vote_D
# CC10_Senate1Vote_D_post
# CC10_Senate1Vote_F
# CC10_Senate1Vote_F_post
# CC10_Senate2Vote_A
# CC10_Senate2Vote_A_post
# CC10_Senate2Vote_B
# CC10_Senate2Vote_B_post
# CC10_Senate2Vote_D
# CC10_Senate2Vote_D_post
# CC10_Senate2Vote_F
# CC14_CurrentSen2Gender_post
# CC14_CurrentSen2Name
# CC14_CurrentSen2Name_post
# CC14_CurrentSen2Party
# CC14_CurrentSen2Party_post
# CC14_DIST1
# CC14_DISTRC1
# CC14_DISTRC2
# CC14_DISTRC3
# CC14_DISTRC4
# CC14_DISTRC5
# CC14_Ebola1
# CC14_Ebola2
# CC14_Ebola2_a
# CC14_Ebola2_b
# CC14_Ebola2_c
# CC14_GovCand1Incumbent
# CC14_GovCand1Incumbent_post
# CC14_GovCand1Name
# CC14_GovCand1Name_post
# CC14_GovCand1Party
# CC14_GovCand1Party_post
# CC14_GovCand2Incumbent
# CC14_GovCand2Incumbent_post
# CC14_GovCand2Name
# CC14_GovCand2Name_post
# CC14_GovCand2Party
# CC14_GovCand2Party_post
# CC14_HouseCand1Gender
# CC14_HouseCand1Gender_post
# CC14_HouseCand1Incumbent
# CC14_HouseCand1Incumbent_post
# CC14_HouseCand1Name
# CC14_HouseCand1Name_post
# CC14_HouseCand1Party
# CC14_HouseCand1Party_post
# CC14_HouseCand2Gender
# CC14_HouseCand2Gender_post
# CC14_HouseCand2Incumbent
# CC14_HouseCand2Incumbent_post
# CC14_HouseCand2Name
# CC14_HouseCand2Name_post
# CC14_HouseCand2Party
# CC14_HouseCand2Party_post
# CC14_HouseCand3Gender
# CC14_HouseCand3Gender_post
# CC14_HouseCand3Name
# CC14_HouseCand3Name_post
# CC14_HouseCand3Party
# CC14_HouseCand3Party_post
# CC14_LegName
# CC14_LegName_post
# CC14_LowerChamberName
# CC14_LowerChamberName_post
# CC14_MCBig5_1
# CC14_MCBig5_2
# CC14_MCBig5_3
# CC14_MCBig5_4
# CC14_MCBig5_5
# CC14_MCMIL_1
# CC14_MCMIL_2
# CC14_MCMIL_3
# CC14_REP1
# CC14_REP2
# CC14_REP2x
# CC14_RISK1
# CC14_RISK2a
# CC14_RISK2b
# CC14_SEN2a
# CC14_SEN2b
# CC14_SenCand1Gender
# CC14_SenCand1Gender_post
# CC14_SenCand1Incumbent
# CC14_SenCand1Incumbent_post
# CC14_SenCand1Name
# CC14_SenCand1Name2
# CC14_SenCand1Name2_post
# CC14_SenCand1Name_post
# CC14_SenCand1Party
# CC14_SenCand1Party2
# CC14_SenCand1Party2_post
# CC14_SenCand1Party_post
# CC14_SenCand2Gender
# CC14_SenCand2Gender_post
# CC14_SenCand2Incumbent
# CC14_SenCand2Incumbent_post
# CC14_SenCand2Name
# CC14_SenCand2Name2
# CC14_SenCand2Name2_post
# CC14_SenCand2Name_post
# CC14_SenCand2Party
# CC14_SenCand2Party2
# CC14_SenCand2Party2_post
# CC14_SenCand2Party_post
# CC14_SenCand3Gender
# CC14_SenCand3Gender_post
# CC14_SenCand3Name
# CC14_SenCand3Name2
# CC14_SenCand3Name2_post
# CC14_SenCand3Name_post
# CC14_SenCand3Party
# CC14_SenCand3Party2
# CC14_SenCand3Party2_post
# CC14_SenCand3Party_post
# CC14_big5_a
# CC14_big5_b
# CC14_big5_c
# CC14_big5_d
# CC14_big5_e
# CC14_big5_f
# CC14_big5_g
# CC14_big5_h
# CC14_big5_i
# CC14_big5_j
# CC14_open1
# CC14_open2
# CC14_open3
# CC14_open4
# CC14_open5
# CC14_open6
# StateAbbr_10
# StateAbbr_12
# StateAbbr_14
# V202_wave2010
# V292_post_wave2010
# Xreligpew_protestant_12
# Xreligpew_protestant_14
# addrlength_1_10
# addrlength_1_12
# addrlength_1_14
# addrlength_2_10
# addrlength_2_12
# addrlength_2_14
# birthyr_10
# birthyr_12
# birthyr_14
# cdid112_10
# cdid112_12
# cdid112_post_10
# cdid112_post_12
# cdid113_12
# cdid113_post_12
# cdid114_14
# cdid114_post_14
# child18_10
# child18_12
# child18_14
# child18num_10
# child18num_12
# child18num_14
# citylength_1_10
# citylength_1_12
# citylength_1_14
# citylength_2_10
# citylength_2_12
# citylength_2_14
# countyfips_10
# countyfips_12
# countyfips_14
# countyfips_post_10
# countyfips_post_12
# countyfips_post_14
# countyname_10
# countyname_12
# countyname_14
# countyname_post_10
# countyname_post_12
# countyname_post_14
# educ_10
# educ_12
# educ_14
# educ_post_12
# educ_post_14
# employ_10
# employ_12
# employ_14
# employ_t_10
# employ_t_12
# employ_t_14
# employercat_12
# employercat_14
# endtime_10
# endtime_12
# endtime_14
# endtime_post_10
# endtime_post_12
# endtime_post_14
# faminc_10
# faminc_12
# faminc_14
# gender_10
# gender_12
# gender_14
# govtlevel_12
# govtlevel_14
# hadjob_12
# hadjob_14
# healthins_1_10
# healthins_1_12
# healthins_1_14
# healthins_2_10
# healthins_2_12
# healthins_2_14
# healthins_3_10
# healthins_3_12
# healthins_3_14
# healthins_4_10
# healthins_4_12
# healthins_4_14
# healthins_5_10
# healthins_5_12
# healthins_5_14
# healthins_6_10
# healthins_6_12
# healthins_6_14
# hispanic_10
# hispanic_12
# hispanic_14
# hispanic_post_12
# hispanic_post_14
# ideo5_10
# ideo5_12
# ideo5_14
# immstat_10
# immstat_12
# immstat_14
# industryclass_12
# industryclass_14
# inputstate_10
# inputstate_12
# inputstate_14
# inputstate_post_10
# inputstate_post_12
# inputstate_post_14
# inputzip
# inputzip_post
# inputzip_wave2012
# internethome_10
# internethome_12
# internethome_14
# internetwork_10
# internetwork_12
# internetwork_14
# investor_10
# investor_12
# investor_14
# investor_14_a
# marstat_10
# marstat_12
# marstat_14
# matched
# milstat_1_10
# milstat_1_12
# milstat_1_14
# milstat_2_10
# milstat_2_12
# milstat_2_14
# milstat_3_10
# milstat_3_12
# milstat_3_14
# milstat_4_10
# milstat_4_12
# milstat_4_14
# milstat_5_10
# milstat_5_12
# milstat_5_14
# newsint_10
# newsint_12
# newsint_14
# numemployees_12
# numemployees_14
# occupationcat_12
# occupationcat_14
# ownhome_10
# ownhome_12
# ownhome_14
# ownhome_t_10
# ownhome_t_12
# ownhome_t_14
# partyaffiliation
# pew_bornagain_10
# pew_bornagain_12
# pew_bornagain_14
# pew_churatd_10
# pew_churatd_12
# pew_churatd_14
# pew_prayer_10
# pew_prayer_12
# pew_prayer_14
# pew_religimp_10
# pew_religimp_12
# pew_religimp_14
# phone_10
# phone_12
# phone_14
# pid3_10
# pid3_12
# pid3_14
# pid3_t_10
# pid3_t_12
# pid3_t_14
# pid7_10
# pid7_12
# pid7_14
# race_10
# race_12
# race_14
# race_other_10
# race_other_12
# race_other_14
# race_post_12
# race_post_14
# regulation_14
# regzip_10
# regzip_12
# regzip_14
# regzip_confirm_12
# regzip_confirm_14
# regzip_post_10
# regzip_post_12
# regzip_post_14
# relighpew_hindu_t_14
# religpew_10
# religpew_12
# religpew_14
# religpew_advent_10
# religpew_advent_12
# religpew_advent_14
# religpew_advent_t_10
# religpew_advent_t_12
# religpew_advent_t_14
# religpew_baptist_10
# religpew_baptist_12
# religpew_baptist_14
# religpew_baptist_t_10
# religpew_baptist_t_12
# religpew_baptist_t_14
# religpew_buddhist_10
# religpew_buddhist_12
# religpew_buddhist_14
# religpew_buddhist_t_10
# religpew_buddhist_t_12
# religpew_buddhist_t_14
# religpew_catholic_10
# religpew_catholic_12
# religpew_catholic_14
# religpew_catholic_t_10
# religpew_catholic_t_12
# religpew_catholic_t_14
# religpew_christian_10
# religpew_christian_12
# religpew_christian_14
# religpew_christian_t_10
# religpew_christian_t_12
# religpew_christian_t_14
# religpew_congreg_10
# religpew_congreg_12
# religpew_congreg_14
# religpew_congreg_t_10
# religpew_congreg_t_12
# religpew_congreg_t_14
# religpew_episcop_10
# religpew_episcop_12
# religpew_episcop_14
# religpew_episcop_t_10
# religpew_episcop_t_12
# religpew_episcop_t_14
# religpew_hindu_10
# religpew_hindu_12
# religpew_hindu_14
# religpew_hindu_t_10
# religpew_hindu_t_12
# religpew_holiness_10
# religpew_holiness_12
# religpew_holiness_14
# religpew_holiness_t_10
# religpew_holiness_t_12
# religpew_holiness_t_14
# religpew_jewish_10
# religpew_jewish_12
# religpew_jewish_14
# religpew_jewish_t_10
# religpew_jewish_t_12
# religpew_jewish_t_14
# religpew_lutheran_10
# religpew_lutheran_12
# religpew_lutheran_14
# religpew_lutheran_t_10
# religpew_lutheran_t_12
# religpew_lutheran_t_14
# religpew_methodist_10
# religpew_methodist_12
# religpew_methodist_14
# religpew_methodist_t_10
# religpew_methodist_t_12
# religpew_methodist_t_14
# religpew_mormon_10
# religpew_mormon_12
# religpew_mormon_14
# religpew_mormon_t_10
# religpew_mormon_t_12
# religpew_mormon_t_14
# religpew_muslim_10
# religpew_muslim_12
# religpew_muslim_14
# religpew_muslim_t_10
# religpew_muslim_t_12
# religpew_muslim_t_14
# religpew_nondenom_10
# religpew_nondenom_12
# religpew_nondenom_14
# religpew_nondenom_t_10
# religpew_nondenom_t_12
# religpew_nondenom_t_14
# religpew_orthodox_10
# religpew_orthodox_12
# religpew_orthodox_14
# religpew_orthodox_t_10
# religpew_orthodox_t_12
# religpew_orthodox_t_14
# religpew_pentecost_10
# religpew_pentecost_12
# religpew_pentecost_14
# religpew_pentecost_t_10
# religpew_pentecost_t_12
# religpew_pentecost_t_14
# religpew_presby_10
# religpew_presby_12
# religpew_presby_14
# religpew_presby_t_10
# religpew_presby_t_12
# religpew_presby_t_14
# religpew_protestant_10
# religpew_protestant_12
# religpew_protestant_14
# religpew_protestant_t_10
# religpew_protestant_t_12
# religpew_protestant_t_14
# religpew_reformed_10
# religpew_reformed_12
# religpew_reformed_14
# religpew_reformed_t_10
# religpew_reformed_t_12
# religpew_reformed_t_14
# religpew_t_10
# religpew_t_12
# religpew_t_14
# reszip_10
# reszip_12
# reszip_14
# reszip_confirm_12
# reszip_confirm_post_12
# reszip_post_10
# reszip_post_12
# reszip_post_14
# sourcerec_post
# starttime_10
# starttime_12
# starttime_14
# starttime_post_10
# starttime_post_12
# starttime_post_14
# stateFIPScode_10
# stateFIPScode_12
# state_cl
# union_10
# union_12
# union_14
# unionhh_10
# unionhh_12
# unionhh_14
# votereg_10
# votereg_12
# votereg_14
# votereg_f_10
# votereg_f_12
# votereg_f_14
# votereg_f_post_10
# votereg_f_post_14
# votereg_post_10
# votereg_post_14
# validated_reg_10
# validated_reg_12
# validated_reg_14
# VV_general_10
# VV_general_12
# VV_general_14
# VV_primary_10
# VV_primary_12
# VV_primary_14
# VV_pres_primary_12

# %%
# Discard open questions
cols_open = [col for col in df_cces.columns if col.endswith('_t') or '_t_' in col or col.endswith('_other')]
print(f'{len(cols_open)} open questions detected.')
df_cces.drop(cols_open, axis=1, inplace=True)
# Out:
# 151 open questions detected.

# %%
# Discard contextual variables
patterns = [
    'CurrentGov', 'CurrentHouse', 'CurrentSen1', 'CurrentSen2', 'GovCand', 'HouseCand',
    'HouseSeat', 'LegName', 'LowerChamberName', 'OtherGovCand', 'OtherHouseCand',
    'SenCand', 'FormerHouse', 'HouseVote', 'Senate1Vote', 'Senate2Vote', 'Ohousecan2party',
    'Otherhousecandidate2party', 'Rsenatecandidategender'
]
cols_context = []
for col in df_cces.columns:
    for pattern in patterns:
        if pattern in col:
            cols_context.append(col)
print(f'{len(cols_context)} contextual variables detected.')
df_cces.drop(cols_context, axis=1, inplace=True)
# Out:
# 380 contextual variables detected.

# %%
# Check
for col in df_cces.columns:
        print(col)
# Out:
# caseid
# weight
# CC10_301_1
# CC10_301_2
# CC10_301_3
# CC10_301_4
# CC10_301_5
# CC10_301b
# CC10_301c
# CC10_302
# CC10_304
# CC10_305
# CC10_308a
# CC10_308b
# CC10_308c
# CC10_308d
# CC10_308e
# CC10_309a
# CC10_309b
# CC10_309c
# CC10_309d
# CC10_310a
# CC10_310b
# CC10_310c
# CC10_310d
# CC10_315a
# CC10_315b
# CC10_315c
# CC10_316
# CC10_317
# CC10_320
# CC10_321
# CC10_322_1
# CC10_322_2
# CC10_322_3
# CC10_322_4
# CC10_322_7
# CC10_322_8
# CC10_324
# CC10_325
# CC10_326
# CC10_327
# CC10_328
# CC10_329
# CC10_330A
# CC10_330B
# CC10_330C
# CC10_330D
# CC10_330E
# CC10_330F
# CC10_330G
# CC10_330H
# CC10_330I
# CC10_330J
# CC10_334E
# CC10_334Hb
# CC10_334Ib
# CC10_335a1
# CC10_335a2
# CC10_335b1
# CC10_335b2
# CC10_335c1
# CC10_335c2
# CC10_341A
# inputstate_14
# inputstate_post_10
# inputstate_post_12
# inputstate_post_14
# inputzip
# inputzip_post
# inputzip_wave2012
# internethome_10
# internethome_12
# internethome_14
# internetwork_10
# internetwork_12
# internetwork_14
# investor_10
# investor_12
# investor_14
# investor_14_a
# marstat_10
# marstat_12
# marstat_14
# matched
# milstat_1_10
# milstat_1_12
# milstat_1_14
# milstat_2_10
# milstat_2_12
# milstat_2_14
# milstat_3_10
# milstat_3_12
# milstat_3_14
# milstat_4_10
# milstat_4_12
# milstat_4_14
# milstat_5_10
# milstat_5_12
# milstat_5_14
# newsint_10
# newsint_12
# newsint_14
# numemployees_12
# numemployees_14
# occupationcat_12
# occupationcat_14
# ownhome_10
# ownhome_12
# ownhome_14
# partyaffiliation
# pew_bornagain_10
# pew_bornagain_12
# pew_bornagain_14
# pew_churatd_10
# pew_churatd_12
# pew_churatd_14
# pew_prayer_10
# pew_prayer_12
# pew_prayer_14
# pew_religimp_10
# pew_religimp_12
# pew_religimp_14
# phone_10
# phone_12
# phone_14
# pid3_10
# pid3_12
# pid3_14
# pid7_10
# pid7_12
# pid7_14
# race_10
# race_12
# race_14
# race_other_10
# race_other_12
# race_other_14
# race_post_12
# race_post_14
# regulation_14
# regzip_10
# regzip_12
# regzip_14
# regzip_confirm_12
# regzip_confirm_14
# regzip_post_10
# regzip_post_12
# regzip_post_14
# religpew_10
# religpew_12
# religpew_14
# religpew_advent_10
# religpew_advent_12
# religpew_advent_14
# religpew_baptist_10
# religpew_baptist_12
# religpew_baptist_14
# religpew_buddhist_10
# religpew_buddhist_12
# religpew_buddhist_14
# religpew_catholic_10
# religpew_catholic_12
# religpew_catholic_14
# religpew_christian_10
# religpew_christian_12
# religpew_christian_14
# religpew_congreg_10
# religpew_congreg_12
# religpew_congreg_14
# religpew_episcop_10
# religpew_episcop_12
# religpew_episcop_14
# religpew_hindu_10
# religpew_hindu_12
# religpew_hindu_14
# religpew_holiness_10
# religpew_holiness_12
# religpew_holiness_14
# religpew_jewish_10
# religpew_jewish_12
# religpew_jewish_14
# religpew_lutheran_10
# religpew_lutheran_12
# religpew_lutheran_14
# religpew_methodist_10
# religpew_methodist_12
# religpew_methodist_14
# religpew_mormon_10
# religpew_mormon_12
# religpew_mormon_14
# religpew_muslim_10
# religpew_muslim_12
# religpew_muslim_14
# religpew_nondenom_10
# religpew_nondenom_12
# religpew_nondenom_14
# religpew_orthodox_10
# religpew_orthodox_12
# religpew_orthodox_14
# religpew_pentecost_10
# religpew_pentecost_12
# religpew_pentecost_14
# religpew_presby_10
# religpew_presby_12
# religpew_presby_14
# religpew_protestant_10
# religpew_protestant_12
# religpew_protestant_14
# religpew_reformed_10
# religpew_reformed_12
# religpew_reformed_14
# reszip_10
# reszip_12
# reszip_14
# reszip_confirm_12
# reszip_confirm_post_12
# reszip_post_10
# reszip_post_12
# reszip_post_14
# sourcerec_post
# starttime_10
# starttime_12
# starttime_14
# starttime_post_10
# starttime_post_12
# starttime_post_14
# stateFIPScode_10
# stateFIPScode_12
# state_cl
# union_10
# union_12
# union_14
# unionhh_10
# unionhh_12
# unionhh_14
# votereg_10
# votereg_12
# votereg_14
# votereg_f_10
# votereg_f_12
# votereg_f_14
# votereg_f_post_10
# votereg_f_post_14
# votereg_post_10
# votereg_post_14
# validated_reg_10
# validated_reg_12
# validated_reg_14
# VV_general_10
# VV_general_12
# VV_general_14
# VV_primary_10
# VV_primary_12
# VV_primary_14
# VV_pres_primary_12

# %%
# Look at unusual column names
for col in df_cces.columns:
    if not col.startswith('CC') and not col.endswith(('_10', '_12', '_14')):
        print(col)
# Out:
# caseid
# weight
# V202_wave2010
# V292_post_wave2010
# inputzip
# inputzip_post
# inputzip_wave2012
# investor_14_a
# matched
# partyaffiliation
# sourcerec_post
# state_cl

# %%
# Omit variables not mentioned in codebook which are not of interest
df_cces.drop(['state_cl', 'sourcerec_post', 'V202_wave2010', 'V292_post_wave2010', 'inputzip',
              'inputzip_post', 'inputzip_wave2012', 'investor_14_a', 'matched', 'partyaffiliation'], axis=1, inplace=True)

# %%
# Deal with district identifiers
df_cces['cdid112_10'] = df_cces['cdid112_10'].astype(int)
df_cces['cdid113_12'] = df_cces['cdid113_12'].astype(int)
df_cces['cdid114_14'] = df_cces['cdid114_14'].astype(int)

# %%
# Check # of discrepancies in district id between pre- and post-election survey
print('2010:', np.sum(df_cces['cdid112_10'] != df_cces['cdid112_post_10'].astype(int)))
print('2012:', np.sum(df_cces['cdid113_12'] != df_cces['cdid113_post_12'].astype(int)))
print('2014:', np.sum(df_cces['cdid114_14'] != df_cces['cdid114_post_14'].astype(int)))
# Out:
# 2010: 109
# 2012: 23
# 2014: 36

# %%
# Rename cd ids such that we get one common variable in long format
df_cces.rename({'cdid112_10': 'cdid_10',
                'cdid113_12': 'cdid_12',
                'cdid114_14': 'cdid_14'}, axis=1, inplace=True)

# %%
# Get columns per year
# 2010
cols_2010 = [col for col in df_cces.columns if col.startswith('CC10_') or col.endswith('_10')]
assert len(cols_2010) == len(set(cols_2010)) # ensure that colnames are unique

# %%
# Check
for col in cols_2010:
    if col.startswith(('CC12', 'CC14')) or col.endswith(('_12', '_14')):
        print(col)
# Out:
# CC12_387_10
# CC12_399_10
# CC12_418bx_10
# CC14_387_10
# CC14_418bx_10

# %%
# Omit columns from other waves accidentally ending up in 2010 subset
cols_2010 = [col for col in cols_2010 if not col.startswith(('CC12', 'CC14'))]

# %%
# 2012
cols_2012 = [col for col in df_cces.columns if col.startswith('CC12_') or col.endswith('_12')]
assert len(cols_2012) == len(set(cols_2012)) # ensure that colnames are unique

# %%
# Check
for col in cols_2012:
    if col.startswith(('CC10', 'CC14')) or col.endswith(('_10', '_14')):
        print(col)
# Out:
# CC12_387_10
# CC12_399_10
# CC12_418bx_10
# CC14_387_12

# %%
# Omit column from other wave accidentally ending up in 2012 subset
cols_2012.remove('CC14_387_12')

# %%
# 2014
cols_2014 = [col for col in df_cces.columns if col.startswith('CC14_') or col.endswith('_14')]
assert len(cols_2014) == len(set(cols_2014)) # ensure that colnames are unique

# %%
# Check
for col in cols_2014:
    if col.startswith(('CC10', 'CC12')) or col.endswith(('_10', '_12')):
        print(col)
# Out:
# CC14_387_10
# CC14_387_12
# CC14_418bx_10

# %%
df_cces
# Out:
#       caseid    weight CC10_301_1 CC10_301_2 CC10_301_3 CC10_301_4 CC10_301_5  \
# 0      25233  0.538062        Yes        Yes        Yes        Yes         No
# 1      38716  3.470877        Yes         No        Yes        Yes         No
# 2       7796  0.602477         No        Yes        Yes        Yes         No
# 3      78113  0.264208        Yes        Yes        Yes        Yes         No
# 4      63800  0.196632        Yes        Yes        Yes         No         No
# ...      ...       ...        ...        ...        ...        ...        ...
# 9495   57290  1.146715         No         No        Yes        Yes         No
# 9496   57315  1.171217         No         No         No        Yes         No
# 9497   57399  0.424949         No        Yes        Yes         No         No
# 9498   59331  0.505942         No        Yes         No        Yes         No
# 9499   66538  1.665605         No        Yes        Yes         No         No
#
#            CC10_301b CC10_301c               CC10_302  ...  \
# 0               Both     Print      Gotten much worse  ...
# 1                NaN      Both  Stayed about the same  ...
# 2               Both     Print           Gotten worse  ...
# 3               Both    Online          Gotten better  ...
# 4               Both      Both          Gotten better  ...
# ...              ...       ...                    ...  ...
# 9495             NaN    Online          Gotten better  ...
# 9496             NaN       NaN  Stayed about the same  ...
# 9497            Both     Print          Gotten better  ...
# 9498  Local Newscast       NaN           Gotten worse  ...
# 9499  Local Newscast     Print  Stayed about the same  ...
#
#                     validated_reg_10 validated_reg_12 validated_reg_14  \
# 0                         Registered       Registered   No match found
# 1                         Registered       Registered       Registered
# 2                         Registered       Registered       Registered
# 3                         Registered       Registered       Registered
# 4                         Registered       Registered       Registered
# ...                              ...              ...              ...
# 9495                      Registered       Registered       Registered
# 9496                      Registered       Registered       Registered
# 9497  On multiple registration lists       Registered       Registered
# 9498                      Registered       Registered       Registered
# 9499                  No match found   No match found   No match found
#
#                     VV_general_10            VV_general_12  \
# 0     In person or unknown method                In person
# 1                      Mail voter               Mail voter
# 2                     Early voter              Early voter
# 3                  Absentee voter           Absentee voter
# 4                     Early voter                In person
# ...                           ...                      ...
# 9495          Confirmed Non-voter  Voted by unknown method
# 9496  In person or unknown method                In person
# 9497          Confirmed Non-voter                In person
# 9498  In person or unknown method                In person
# 9499                    Unmatched                Unmatched
#
#                 VV_general_14            VV_primary_10  \
# 0                   Unmatched         Voted in Primary
# 1                  Mail voter         Voted in Primary
# 2                 Early voter         Voted in Primary
# 3              Absentee voter         Voted in Primary
# 4                   In person  Did not vote in primary
# ...                       ...                      ...
# 9495  Voted by unknown method  Did not vote in primary
# 9496      Confirmed Non-voter  Did not vote in primary
# 9497      Confirmed Non-voter  Did not vote in primary
# 9498                In person         Voted in Primary
# 9499                Unmatched                Unmatched
#
#                 VV_primary_12            VV_primary_14      VV_pres_primary_12
# 0            Voted in Primary                Unmatched  No primary vote record
# 1            Voted in Primary         Voted in Primary  No primary vote record
# 2            Voted in Primary         Voted in Primary  No primary vote record
# 3            Voted in Primary         Voted in Primary  No primary vote record
# 4            Voted in Primary         Voted in Primary  No primary vote record
# ...                       ...                      ...                     ...
# 9495  Did not vote in primary  Did not vote in primary  No primary vote record
# 9496  Did not vote in primary  Did not vote in primary  No primary vote record
# 9497  Did not vote in primary  Did not vote in primary  No primary vote record
# 9498         Voted in Primary         Voted in Primary  No primary vote record
# 9499                Unmatched                Unmatched               Unmatched
#
# [9500 rows x 1117 columns]

# %%
# Write a function to get rootnames (i.e., without CC10, _10)
def get_root_names(col_list: list, yy_end):
    root_names = []
    for col in col_list:
        if col.startswith('CC') and col.endswith(yy_end):
            split = col.split('_')
            root_name = '_'.join(split[1:])
            root_names.append(root_name)
        elif col.startswith('CC'):
            split = col.split('_')
            root_name = '_'.join(split[1:])
            root_names.append(root_name)
        elif col.endswith(yy_end):
            split = col.split('_')
            root_name = '_'.join(split[:-1])
            root_names.append(root_name)
        else:
            root_names.append(col)
            
    return root_names

# %%
cols_2010 = set(get_root_names(cols_2010, '_10'))
cols_2012 = set(get_root_names(cols_2012, '_12'))
cols_2014 = set(get_root_names(cols_2014, '_14'))

# %%
# In 2012 & 2014 there are a lot more vars compared to 2010
# However, the vast majority of the additional vars in 2012
# and 2014 are not of main interest for this project
len(cols_2010), len(cols_2012), len(cols_2014)
# Out:
# (246, 426, 443)

# %%
# Get common vars across all three waves
cols_common = cols_2010.intersection(cols_2012, cols_2014)
print(f'There are {len(cols_common)} common variables across all three waves.')
# Out:
# There are 223 common variables across all three waves.

# %%
# Exclude 
# - unvalidated registration & turnout (intention 354); except turnout 2008
# - reasons for not voting & mode of voting
# - all columns containing response category "I did not vote"
cols_drop = [
    'regzip', 'regzip_post', 'StateAbbr', 'countyfips', 'countyfips_post',
    'countyname', 'countyname_post', 'votereg', 'regzip', 'regzip_post',
    'votereg_f', '352b', '354', '401', '402a', '402b', '403', '405', '410b',
    '410b_nv', '411', '411_nv', '412', '412_nv', '412a', '412b', '413a', '413b',
    '413c', '413d', 'reszip', 'reszip_post', 'starttime', 'starttime_post',
    'validated_reg', 'race_other', 'endtime', 'endtime_post'
]
for col in cols_drop:
    cols_common.discard(col)
    
print(f'Now we are left with {len(cols_common)} variables.')
# Out:
# Now we are left with 187 variables.

# %%
# Create subsets per wave including only the 187 common variables
cols_2010 = ['CC10_' + col if col[0].isdigit() else col + '_10' for col in cols_common]
cols_2010.sort()
assert len(cols_2010) == len(cols_common)
cols_2012 = ['CC12_' + col if col[0].isdigit() else col + '_12' for col in cols_common]
cols_2012.sort()
assert len(cols_2012) == len(cols_common)
cols_2014 = ['CC14_' + col if col[0].isdigit() else col + '_14' for col in cols_common]
cols_2014.sort()
assert len(cols_2014) == len(cols_common)

# %%
# Create new data frames per year
df_cces10 = df_cces[['caseid', 'weight'] + cols_2010].copy()
df_cces12 = df_cces[['caseid', 'weight'] + cols_2012].copy()
df_cces14 = df_cces[['caseid', 'weight'] + cols_2014].copy()
df_cces10.shape[1], df_cces12.shape[1], df_cces14.shape[1]
# Out:
# (189, 189, 189)

# %%
# Add variable for year in every newly created data frame
df_cces10.insert(2, 'year', 2010)
df_cces12.insert(2, 'year', 2012)
df_cces14.insert(2, 'year', 2014)

# %%
# Write function to rename the variables, similar to get_root_names
def rename_df(df: pd.DataFrame, yy_end):
    dic_rename = {}
    for col in df.columns:
        if col.startswith('CC') and col.endswith(yy_end):
            split = col.split('_')
            root_name = '_'.join(split[1:])
            dic_rename[col] = root_name
        elif col.startswith('CC'):
            split = col.split('_')
            root_name = '_'.join(split[1:])
            dic_rename[col] = root_name
        elif col.endswith(yy_end):
            split = col.split('_')
            root_name = '_'.join(split[:-1])
            dic_rename[col] = root_name
        else:
            dic_rename[col] = col
            
    df.rename(columns=dic_rename, inplace=True)

# %%
# Apply function to the dfs
rename_df(df_cces10, '_10')
rename_df(df_cces12, '_12')
rename_df(df_cces14, '_14')

# %%
# Merge data frames ==> long format
df_cces_clean = pd.concat([df_cces10, df_cces12, df_cces14]).reset_index(drop=True)

# %%
# Glimpse at new data frame in long format
df_cces_clean
# Out:
#        caseid    weight  year 301_1 301_2 301_3 301_4 301_5            301b  \
# 0       25233  0.538062  2010   Yes   Yes   Yes   Yes    No            Both
# 1       38716  3.470877  2010   Yes    No   Yes   Yes    No             NaN
# 2        7796  0.602477  2010    No   Yes   Yes   Yes    No            Both
# 3       78113  0.264208  2010   Yes   Yes   Yes   Yes    No            Both
# 4       63800  0.196632  2010   Yes   Yes   Yes    No    No            Both
# ...       ...       ...   ...   ...   ...   ...   ...   ...             ...
# 28495   57290  1.146715  2014    No    No    No    No   Yes             NaN
# 28496   57315  1.171217  2014    No    No    No    No   Yes             NaN
# 28497   57399  0.424949  2014    No   Yes    No    No    No  Local Newscast
# 28498   59331  0.505942  2014    No   Yes    No   Yes    No  Local Newscast
# 28499   66538  1.665605  2014    No   Yes    No    No    No  Local Newscast
#
#          301c  ...                                  religpew_mormon  \
# 0       Print  ...                                              NaN
# 1        Both  ...                                              NaN
# 2       Print  ...  The Church of Jesus Christ of Latter-day Saints
# 3      Online  ...                                              NaN
# 4        Both  ...                                              NaN
# ...       ...  ...                                              ...
# 28495     NaN  ...                                              NaN
# 28496     NaN  ...                                              NaN
# 28497     NaN  ...                                              NaN
# 28498     NaN  ...  The Church of Jesus Christ of Latter-day Saints
# 28499     NaN  ...                                              NaN
#
#       religpew_muslim religpew_nondenom religpew_orthodox religpew_pentecost  \
# 0                 NaN               NaN               NaN                NaN
# 1                 NaN               NaN               NaN                NaN
# 2                 NaN               NaN               NaN                NaN
# 3                 NaN               NaN               NaN                NaN
# 4                 NaN               NaN               NaN                NaN
# ...               ...               ...               ...                ...
# 28495             NaN               NaN               NaN                NaN
# 28496             NaN               NaN               NaN                NaN
# 28497             NaN               NaN               NaN                NaN
# 28498             NaN               NaN               NaN                NaN
# 28499             NaN               NaN               NaN                NaN
#
#       religpew_presby religpew_protestant religpew_reformed  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN           Methodist               NaN
# ...               ...                 ...               ...
# 28495             NaN                 NaN               NaN
# 28496             NaN                 NaN               NaN
# 28497             NaN                 NaN               NaN
# 28498             NaN                 NaN               NaN
# 28499             NaN                 NaN               NaN
#
#                                                    union  \
# 0               I formerly was a member of a labor union
# 1      I am not now, nor have I been, a member of a l...
# 2               I formerly was a member of a labor union
# 3      I am not now, nor have I been, a member of a l...
# 4      I am not now, nor have I been, a member of a l...
# ...                                                  ...
# 28495  I am not now, nor have I been, a member of a l...
# 28496  I am not now, nor have I been, a member of a l...
# 28497  I am not now, nor have I been, a member of a l...
# 28498      Yes, I am currently a member of a labor union
# 28499           I formerly was a member of a labor union
#
#                                                  unionhh
# 0      No, no one in my household has ever been a mem...
# 1      No, no one in my household has ever been a mem...
# 2      A member of my household was formerly a member...
# 3      No, no one in my household has ever been a mem...
# 4      No, no one in my household has ever been a mem...
# ...                                                  ...
# 28495  A member of my household was formerly a member...
# 28496  No, no one in my household has ever been a mem...
# 28497  A member of my household was formerly a member...
# 28498  No, no one in my household has ever been a mem...
# 28499  A member of my household was formerly a member...
#
# [28500 rows x 190 columns]

# %%
# Replace empty strings with NaN
df_cces_clean.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df_cces_clean.replace('', np.nan, inplace=True)

# %%
# Look at proportions of missing values per variable
for col, prop in (df_cces_clean.isna().mean()
                  .sort_values(ascending=False)
                  .items()):
    print(f"{col:<17} {prop:.2f}")
# Out:
# religpew_hindu    1.00
# religpew_muslim   1.00
# religpew_advent   1.00
# religpew_holiness 1.00
# 406c              0.99
# religpew_orthodox 0.99
# religpew_reformed 0.99
# religpew_buddhist 0.99
# 406b_3            0.99
# 406b_2            0.99
# 406b_1            0.99
# religpew_mormon   0.98
# religpew_christian 0.98
# religpew_congreg  0.98
# religpew_pentecost 0.97
# religpew_episcop  0.97
# religpew_presby   0.96
# religpew_jewish   0.96
# 418bx_8           0.95
# 418bx_2           0.95
# 418bx_10          0.95
# 418bx_6           0.95
# 418bx_7           0.95
# 418bx_9           0.95
# 418bx_1           0.95
# 418bx_5           0.95
# 418bx_4           0.95
# 418bx_3           0.95
# religpew_lutheran 0.94
# religpew_methodist 0.92
# religpew_nondenom 0.88
# religpew_baptist  0.88
# child18num        0.84
# 341M              0.82
# 423c              0.81
# religpew_catholic 0.76
# 355               0.73
# 356               0.72
# 421_rep           0.69
# 421b              0.68
# 417c              0.66
# 390               0.64
# 417bx_8           0.64
# 417bx_1           0.64
# 417bx_2           0.64
# 417bx_3           0.64
# 417bx_5           0.64
# 417bx_6           0.64
# 417bx_7           0.64
# 417bx_4           0.64
# 417bx_9           0.64
# 421_dem           0.63
# 355b              0.58
# religpew_protestant 0.53
# 341I              0.35
# 341G              0.34
# 341J              0.34
# 301c              0.34
# 322_4             0.31
# 341H              0.28
# citylength_2      0.23
# 425b_1            0.23
# 425b_4            0.23
# 425b_3            0.23
# 425b_2            0.23
# 301b              0.22
# addrlength_2      0.22
# 406a              0.08
# 341K              0.07
# hispanic          0.07
# 317               0.06
# 423a              0.05
# 341L              0.04
# internetwork      0.04
# 330E              0.03
# 423b              0.03
# addrlength_1      0.03
# 350               0.02
# citylength_1      0.02
# 329               0.02
# 341R              0.02
# 330F              0.02
# 330C              0.02
# 315a              0.01
# 330H              0.01
# 328               0.01
# 330G              0.01
# 310d              0.01
# 330A              0.01
# 330B              0.01
# 315c              0.01
# 416r              0.01
# 315b              0.01
# 341F              0.01
# 341B              0.01
# 330D              0.01
# 324               0.01
# unionhh           0.01
# 309c              0.01
# 309d              0.01
# 310b              0.01
# 326               0.01
# 310c              0.00
# 308e              0.00
# 308c              0.00
# internethome      0.00
# 308b              0.00
# ownhome           0.00
# 308d              0.00
# 341A              0.00
# 310a              0.00
# phone             0.00
# 415r              0.00
# 309b              0.00
# 327               0.00
# 305               0.00
# 325               0.00
# 341C              0.00
# immstat           0.00
# 321               0.00
# 309a              0.00
# 418a              0.00
# pid7              0.00
# child18           0.00
# 308a              0.00
# 320               0.00
# 316               0.00
# 304               0.00
# 425a              0.00
# 302               0.00
# faminc            0.00
# 422a              0.00
# 422b              0.00
# investor          0.00
# union             0.00
# 301_2             0.00
# 301_3             0.00
# 301_1             0.00
# 301_4             0.00
# 301_5             0.00
# 322_2             0.00
# 322_3             0.00
# 322_1             0.00
# milstat_3         0.00
# milstat_2         0.00
# milstat_1         0.00
# milstat_4         0.00
# milstat_5         0.00
# pew_churatd       0.00
# healthins_4       0.00
# healthins_6       0.00
# healthins_5       0.00
# healthins_3       0.00
# healthins_2       0.00
# healthins_1       0.00
# religpew          0.00
# pew_bornagain     0.00
# pid3              0.00
# ideo5             0.00
# pew_religimp      0.00
# marstat           0.00
# newsint           0.00
# 414_3             0.00
# 417a_6            0.00
# year              0.00
# 417a_5            0.00
# 417a_4            0.00
# 417a_3            0.00
# 417a_2            0.00
# 417a_1            0.00
# 414_7             0.00
# 414_6             0.00
# 414_5             0.00
# 414_4             0.00
# 421a              0.00
# 414_1             0.00
# 414_2             0.00
# VV_general        0.00
# VV_primary        0.00
# birthyr           0.00
# cdid              0.00
# educ              0.00
# employ            0.00
# gender            0.00
# race              0.00
# weight            0.00
# inputstate        0.00
# inputstate_post   0.00
# pew_prayer        0.00
# caseid            0.00

# %%
# Vast majority of columns with very high no of NaN are not of interest
# Discard all columns containing more than 24% NaN
thresh = 0.24
df_cces_clean.dropna(axis=1, thresh=int((1-thresh)*len(df_cces_clean)), inplace=True)
print(f'Now we are left with {df_cces_clean.shape[1]} variables.')
# Out:
# Now we are left with 130 variables.

# %%
# Look at proportions of missing values per variable
for col, prop in (df_cces_clean.isna().mean()
                  .sort_values(ascending=False)
                  .items()):
    print(f"{col:<17} {prop:.2f}")
# Out:
# citylength_2      0.23
# 425b_4            0.23
# 425b_1            0.23
# 425b_2            0.23
# 425b_3            0.23
# 301b              0.22
# addrlength_2      0.22
# 406a              0.08
# 341K              0.07
# hispanic          0.07
# 317               0.06
# 423a              0.05
# 341L              0.04
# internetwork      0.04
# 330E              0.03
# 423b              0.03
# addrlength_1      0.03
# 350               0.02
# citylength_1      0.02
# 329               0.02
# 341R              0.02
# 330F              0.02
# 330C              0.02
# 315a              0.01
# 330H              0.01
# 328               0.01
# 330G              0.01
# 310d              0.01
# 330A              0.01
# 330B              0.01
# 315c              0.01
# 416r              0.01
# 315b              0.01
# 341F              0.01
# 341B              0.01
# 330D              0.01
# 324               0.01
# unionhh           0.01
# 309c              0.01
# 309d              0.01
# 310b              0.01
# 326               0.01
# 310c              0.00
# 308e              0.00
# 308c              0.00
# internethome      0.00
# 308b              0.00
# ownhome           0.00
# 308d              0.00
# 310a              0.00
# 341A              0.00
# phone             0.00
# 415r              0.00
# 309b              0.00
# 327               0.00
# 305               0.00
# 325               0.00
# 341C              0.00
# immstat           0.00
# 321               0.00
# 309a              0.00
# 418a              0.00
# pid7              0.00
# child18           0.00
# 308a              0.00
# 320               0.00
# 316               0.00
# 304               0.00
# 425a              0.00
# 302               0.00
# faminc            0.00
# 422a              0.00
# 422b              0.00
# investor          0.00
# union             0.00
# 301_2             0.00
# 301_4             0.00
# 301_3             0.00
# 301_1             0.00
# 301_5             0.00
# 322_2             0.00
# 322_1             0.00
# 322_3             0.00
# milstat_5         0.00
# milstat_1         0.00
# milstat_2         0.00
# milstat_3         0.00
# milstat_4         0.00
# healthins_1       0.00
# healthins_2       0.00
# religpew          0.00
# healthins_6       0.00
# healthins_5       0.00
# healthins_3       0.00
# healthins_4       0.00
# pew_churatd       0.00
# pew_bornagain     0.00
# pid3              0.00
# ideo5             0.00
# pew_religimp      0.00
# marstat           0.00
# year              0.00
# newsint           0.00
# race              0.00
# pew_prayer        0.00
# inputstate_post   0.00
# 417a_4            0.00
# inputstate        0.00
# VV_general        0.00
# 417a_6            0.00
# 417a_3            0.00
# 421a              0.00
# 417a_2            0.00
# 417a_1            0.00
# weight            0.00
# 414_7             0.00
# 414_6             0.00
# 414_5             0.00
# VV_primary        0.00
# 417a_5            0.00
# 414_4             0.00
# 414_3             0.00
# birthyr           0.00
# cdid              0.00
# 414_2             0.00
# 414_1             0.00
# educ              0.00
# employ            0.00
# gender            0.00
# caseid            0.00

# %%
# Notice that the responses do not contain any NaN
for col, prop in (df_cces_clean.isna().mean()
                  .sort_values(ascending=False)
                  .items()):
    if col in ['VV_primary', 'VV_general']:
        print(f"{col:<17} {prop:.2f}")
# Out:
# VV_general        0.00
# VV_primary        0.00

# %%
# Recode some of the columns, where answer categories are long
df_cces_clean['316'].replace({'Yes. I definitely voted.': 'Yes',
                              'I usually vote, but did not in 2008': 'Usually vote but no',
                              'I am not sure': 'Not sure'}, inplace=True)
df_cces_clean['321'].replace({
   'Global climate change has been established as a serious problem, and immediate action is necessary.': 'Immediate action',
   'There is enough evidence that climate change is taking place and some action should be taken.': 'Some action',
   'Concern about global climate change is exaggerated.  No action is necessary.': 'No action',
   "We don't know enough about global climate change, and more research is necessary before we take any actions.": 'More research',
   'Global climate change is not occurring; this is not a real issue.': 'Climate change is not occurring'
}, inplace=True)
df_cces_clean['324'].replace({
   'By law, a woman should always be able to obtain an abortion as a matter of personal choice': 'Always',
   "The law should permit abortion only in case of rape, incest or when the woman's life is in danger": 'Only rape, incest or life in danger',
   "The law should permit abortion for reasons other than rape, incest, or danger to the woman's life, but only after the ne": 'Not only rape, incest or life in danger',
   "By law, abortion should never be permitted": 'Never'
}, inplace=True)
df_cces_clean['325'].replace({
    'Economy somewhat more important': 'Economy more important',
    'Environment somewhat more important': 'Environment more important',
    'Much more important to protect environment even if we lose jobs or lower our standard of living': 'Environment much more important',
    'Much more important to protect jobs, even if the environment gets worse': 'Economy much more important',
    'Much more important to protect jobs, even if environment worse': 'Economy much more important',
    'Much more important to protect environment even if lose jobs and lower standard of living': 'Environment much more important'
}, inplace=True)
df_cces_clean['union'].replace({
    'I am not now, nor have I been, a member of a labor union': 'No, never',
    'I formerly was a member of a labor union': 'Formerly',
    'Yes, I am currently a member of a labor union': 'Yes, currently'
}, inplace=True)
df_cces_clean['unionhh'].replace({
    'No, no one in my household has ever been a member of a labor union': 'No, never',
    'A member of my household was formerly a member of a labor union, but is not now': 'Formerly',
    'Yes, a member of my household is currently a union member': 'Yes, currently'
}, inplace=True)

# %%
# Recode 415r and 416r
# Remove letters to convert to float
df_cces_clean['415r'].replace({'0- All from tax increases': '0',
                               '100- All from spending cuts': '100'}, inplace=True)
df_cces_clean['416r'].replace({'0- All from sales tax': '0',
                               '100- All from income taxes': '100'}, inplace=True)
# Convert to float
df_cces_clean['415r'] = df_cces_clean['415r'].astype(float)
df_cces_clean['416r'] = df_cces_clean['416r'].astype(float)

# %%
# Both variables contain the value 997 ==> NaN
np.max(df_cces_clean['415r']), np.max(df_cces_clean['416r'])
# Out:
# (997.0, 997.0)

# %%
df_cces_clean['415r'].replace(997.0, np.nan, inplace=True)
df_cces_clean['416r'].replace(997.0, np.nan, inplace=True)

# %%
# Replace $-sign of income variable with empty string and recode
df_cces_clean['faminc'] = df_cces_clean['faminc'].str.replace('$', '', regex=False)
df_cces_clean['faminc'].replace({'less than 10,000': 'Less than 10,000'}, inplace=True)

# %%
# Recode 315a, 315b and 315c which contain same category twice
for col in df_cces_clean.columns:
    if col.startswith('315'):
        df_cces_clean[col].replace(
            {'Never Heard': 'Never Heard of Person'}, inplace=True
        )

# %%
# Harmonize 330A-H between waves (support/oppose in 2010, yes/no in 2012/14)
for col in df_cces_clean.columns:
    if col.startswith('330'):
        df_cces_clean[col].replace({'Oppose': 'No', 'Support': 'Yes'}, inplace=True)

# %%
# Harmonize ideo5 between waves
df_cces_clean['ideo5'].replace({'Very Conservative': 'Very conservative'}, inplace=True)

# %%
# Recode the dependent variables to dummies. Mode of voting is not of our interest.
# Assume that unmatched = abstainers
df_cces_clean['VV_primary'].replace({'Voted in Primary': 'Voted',
                                     'Did not vote in primary': 'Abstained',
                                     'Unmatched': 'Abstained'}, inplace=True)
df_cces_clean['VV_general'].replace({'In person': 'Voted',
                                     'In person or unknown method': 'Voted',
                                     'Voted by unknown method': 'Voted',
                                     'Confirmed Non-voter': 'Abstained',
                                     'Unmatched': 'Abstained',
                                     'Absentee voter': 'Voted',
                                     'Early voter': 'Voted',
                                     'Mail voter': 'Voted'}, inplace=True)

# %%
df_cces_clean['VV_primary'].value_counts()
# Out:
# Abstained    15321
# Voted        13179
# Name: VV_primary, dtype: int64

# %%
df_cces_clean['VV_general'].value_counts()
# Out:
# Voted        21066
# Abstained     7434
# Name: VV_general, dtype: int64

# %%
# Look at dtypes of data frame
df_cces_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28500 entries, 0 to 28499
# Columns: 130 entries, caseid to unionhh
# dtypes: category(105), float64(7), int64(3), object(15)
# memory usage: 8.3+ MB

# %%
# Convert birthyr categorical ==> int64
df_cces_clean['birthyr'] = df_cces_clean['birthyr'].astype(int)

# %%
# Convert object dtypes to categorical
for col in df_cces_clean.select_dtypes('object').columns:
    df_cces_clean[col] = df_cces_clean[col].astype('category')

# %%
# Convert all ordered categories to unordered categories
for col in df_cces_clean.columns:
    if pd.api.types.is_categorical_dtype(df_cces_clean[col]) and df_cces_clean[col].cat.ordered:
        df_cces_clean[col] = df_cces_clean[col].cat.as_unordered()

# %%
# Create ordered categories (only where meaningful / possible)
df_cces_clean['302'].replace({'Not sure': np.nan}, inplace=True)
df_cces_clean['302'] = df_cces_clean['302'].cat.set_categories(
    ['Gotten much worse', 'Gotten worse', 'Stayed about the same',
     'Gotten better', 'Gotten much better'], ordered=True
)
df_cces_clean['320'] = df_cces_clean['320'].cat.set_categories(
    ['Less Strict', 'Kept As They Are', 'More Strict'], ordered=True
)
df_cces_clean['321'] = df_cces_clean['321'].cat.set_categories(
    ['Climate change is not occurring', 'No action',
     'More research', 'Some action', 'Immediate action'], ordered=True
)
df_cces_clean['324'] = df_cces_clean['324'].cat.set_categories(
    ['Never', 'Only rape, incest or life in danger', 
     'Not only rape, incest or life in danger', 'Always'], ordered=True
)
df_cces_clean['325'].replace({'Not sure': np.nan}, inplace=True)
df_cces_clean['325'] = df_cces_clean['325'].cat.set_categories(
    ['Environment much more important', 'Environment more important',
     'About the same', 'Economy more important', 'Economy much more important'],
    ordered=True
)
df_cces_clean['327'] = df_cces_clean['327'].cat.set_categories(
    ['Strongly oppose', 'Somewhat oppose', 
     'Somewhat support', 'Strongly support'], ordered=True
)
df_cces_clean['educ'] = df_cces_clean['educ'].cat.set_categories(
    ['No HS', 'High school graduate', 'Some college', 
     '2-year', '4-year', 'Post-grad'], ordered=True
)
df_cces_clean['ideo5'].replace({'Not sure': np.nan}, inplace=True)
df_cces_clean['ideo5'] = df_cces_clean['ideo5'].cat.set_categories(
    ['Very liberal', 'Liberal', 'Moderate', 
     'Conservative', 'Very conservative'], ordered=True
)
df_cces_clean['newsint'].replace({"Don't know": np.nan}, inplace=True)
df_cces_clean['newsint'] = df_cces_clean['newsint'].cat.set_categories(
    ['Hardly at all', 'Only now and then', 
     'Some of the time', 'Most of the time'], ordered=True
)
df_cces_clean['pew_churatd'].replace({"Don't know": np.nan}, inplace=True)
df_cces_clean['pew_churatd'] = df_cces_clean['pew_churatd'].cat.set_categories(
    ['Never', 'Seldom', 'A few times a year', 'Once or twice a month', 
     'Once a week', 'More than once a week'], ordered=True
)
df_cces_clean['pew_prayer'].replace({"Don't know": np.nan}, inplace=True)
df_cces_clean['pew_prayer'] = df_cces_clean['pew_prayer'].cat.set_categories(
    ['Never', 'Seldom', 'A few times a month', 'Once a week',
    'A few times a week', 'Once a day', 'Several times a day'], ordered=True
)
df_cces_clean['pew_religimp'] = df_cces_clean['pew_religimp'].cat.set_categories(
    ['Not at all important', 'Not too important', 
     'Somewhat important', 'Very important'], ordered=True
)
df_cces_clean['pid7'].replace({'Not sure': np.nan}, inplace=True)
df_cces_clean['pid7'] = df_cces_clean['pid7'].cat.set_categories(
    ['Strong Democrat', 'Not very strong Democrat', 'Lean Democrat', 'Independent', 
     'Lean Republican', 'Not very strong Republican', 'Strong Republican'], ordered=True
)
for col in df_cces_clean.columns:
    if col.startswith('308'):
        df_cces_clean[col].replace({'Not sure': np.nan}, inplace=True)
        df_cces_clean[col] = df_cces_clean[col].cat.set_categories(
            ['Strongly Disapprove', 'Somewhat Disapprove',
             'Somewhat Approve', 'Strongly Approve'], ordered=True
        )
    elif col.startswith('341'):
        df_cces_clean[col].replace({'Not Sure': np.nan}, inplace=True)
        df_cces_clean[col] = df_cces_clean[col].cat.set_categories(
            ['Very Liberal', 'Liberal', 'Somewhat Liberal',
             'Middle of the Road', 'Somewhat Conservative',
             'Conservative', 'Very Conservative'], ordered=True
        )
    elif col.startswith('422'):
        df_cces_clean[col] = df_cces_clean[col].cat.set_categories(
            ['Strongly disagree', 'Somewhat disagree', 
             'Neither agree nor disagree',
             'Somewhat agree', 'Strongly agree'], ordered=True
        )

# %%
''' Unfortunately, the researchers used different income
categories across the 3 survey waves. Hence, we leave it
as a nominal variable for now. '''
df_cces_clean['faminc'].value_counts()
# Out:
# Prefer not to say    3359
# 80,000 - 99,999      2859
# 50,000 - 59,999      2604
# 40,000 - 49,999      2562
# 30,000 - 39,999      2467
# 70,000 - 79,999      2315
# 60,000 - 69,999      2216
# 100,000 - 119,999    2146
# 120,000 - 149,999    1786
# 20,000 - 29,999      1400
# 10,000 - 19,999       922
# 150,000 - 199,999     770
# 150,000 or more       626
# Less than 10,000      569
# 25,000 - 29,999       411
# 20,000 - 24,999       361
# 200,000 - 249,999     304
# 15,000 - 19,999       271
# 10,000 - 14,999       226
# 250,000 - 349,999     179
# 350,000 - 499,999      62
# 500,000 or more        46
# 250,000 or more         5
# Name: faminc, dtype: int64

# %%
''' Check number of instances where a respondent moved from one state
to another between the pre- and a post-election survey within a wave'''
np.sum(df_cces_clean['inputstate'] != df_cces_clean['inputstate_post'])
# Out:
# 32

# %%
# Occurred only 32 times ==> omit inputstate_post
df_cces_clean.drop('inputstate_post', axis=1, inplace=True)

# %%
# Now some variables contain more than 24% missing values
for col, prop in (df_cces_clean.isna().mean()
                  .sort_values(ascending=False)
                  .items()):
    if prop > 0.24:
        print(f"{col:<17} {prop:.2f}")
# Out:
# 341K              0.36
# 341L              0.31

# %%
# Omit those variables
df_cces_clean.drop(['341K', '341L'], axis=1, inplace=True)

# %%
""" Save cleaned data set as parquet, which is much more 
efficient than csv / stata and preserves dtypes """
#df_cces_clean.to_parquet('../Data/CCES/CCES_Panel_cleaned.parquet')
# Out:
# ' Save cleaned data set as parquet, which is much more \nefficient than csv / stata and preserves dtypes '
